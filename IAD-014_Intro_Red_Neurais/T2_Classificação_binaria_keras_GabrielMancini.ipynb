# %% [markdown]
# # Trabalho #2 - Classificação binária com rede neural deep-learning
#
# Nesse trabalho você vai desenvolver uma rede neural rasa e uma deep-learning, usando a plataforma TensorFlow-Keras, para realizar uma tarefa de classificação binária para reconhecer gatos em imagens e comparar o desempenho das duas redes.

# %% [markdown]
# ## Identificação
#
# Nome: Gabriel Silvestre Mancini

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## 1 - Bibliotecas ##
#
# Em primeiro lugar, execute a célula abaixo para importar algumas bibliotecas Python que são usadas nesse trabalho.
# - [numpy](www.numpy.org) é a biblioteca básica para computação cinetífica usando Python.
# - [h5py](http://www.h5py.org) é uma biblioteca que fornece funções para interagir com banco de dados salvos em arquivos no formato h5.
# - [matplotlib](http://matplotlib.org) é uma biblioteca famosa usada para fazer gráficos com Python.
# - [PIL](http://www.pythonware.com/products/pil/) e [scipy](https://www.scipy.org/) são usadas para testar a sua RNA com novas imagens no final do trabalho.
# - lr_utils é um arquivo com uma função para ler os dados usados nesse trabalho.

# %% [markdown]
# O comando da célula abaixo importa o TensorFlow e verifica a versão que está sendo utilizada.

# %%
import tensorflow as tf
tf.__version__
# Out:
# '2.17.0'

# %% [markdown]
# Como o TensorFlow é um software aberto não existe muita preocupação do desenvolvedor (no caso o Google) de manter a compatibilidade entre as versões. Assim, se você estiver usando uma versão do TensorFlow incompatível com o seu programa, você pode impor o uso de uma versão mais antiga.
#
# Por exemplo o código abaixo importa a versão 2 do TensorFlow, mas se ela não estiver instalada importa a versão instalada.
#
# ```
#  try:
#      import tensorflow.compat.v2 as tf
#  except Exception:
#      import tensorflow as tf
#  print(tf.__version__)
# ```
#
# Outro exemplo, se a versão instalada do TensorFlow for a 2 e o seu programa foi feito para a versão 1, então pode habilitar a versão 2 com o comportamento da versão 1. O código abaixo mostra como fazer isso.
#
# ```
#  import tensorflow as tf
#  print(tf.__version__)
#  tf.enable_v1_behavior()
# ```

# %%
import numpy as np
import matplotlib.pyplot as plt
import h5py
import scipy
from PIL import Image
from scipy import ndimage

# %matplotlib inline

# %% [markdown]
# ## 2 - Visão geral do problema ##
#
# **Definição do problema**:
#
# Nesse trabalho é fornecido um conjunto de dados que contém:
#
#     - um conjunto de imagens de treinamento classificadas como tendo gato (y=1) ou não tendo gato (y=0);
#     - um conjunto de imagens de teste classificadas como tendo gato (y=1) ou não tendo gato (y=0);
#     - a dimensão de cada imagem é (num_px, num_px, 3), onde 3 é o número de canais de cor (RGB);
#     - cada imagem é composta por três matrizes de dimensão: número de linhas = num_px e número de colunas = num_px;
#     - número de imagens do conjunto de treinamento: m_train;
#     - número de imagens do conjunto de teste: m_test.
#
# A partir desses conjuntos de dados, a sua tarefa é desenvolver um sistema baseado em uma rede neural, para processar imagens e classificar corretamente se ela mostra ou não um gato. Para isso, você vai desenvolver algumas redes neurais usando a ferramenta Keras e comparar o desempenho delas.
#
# O uso da ferramenta Keras para desenvolver redes neurais facilita muito o trabalho, pois não exige desenvolver codigos específicos para implementar cada camada da rede, a função de custo, a métrica e principalmente o gradiente descendente.

# %% [markdown]
# ## 3 - Conjunto de dados de treinamento e teste
#
# O conjunto de dados utilizado pode ser obtido em: https://www.kaggle.com/mriganksingh/cat-images-dataset. Para carregar esse conjunto de dados execute o código a seguir.
#
# O termo _orig é adicionado no final dos tensores com os dados de treinamento e teste originais porque vamos processar esses dados.

# %%
# Conjunto de dados de treinamento
train_dataset = h5py.File('/content/drive/MyDrive/T2_CLASSIFICACAO_KERAS/train_catvnoncat.h5', "r")
train_set_x_orig = np.array(train_dataset["train_set_x"][:])
train_set_y = np.array(train_dataset["train_set_y"][:])

# Conjunto de dados de teste
test_dataset = h5py.File('/content/drive/MyDrive/T2_CLASSIFICACAO_KERAS/test_catvnoncat.h5', "r")
test_set_x_orig = np.array(test_dataset["test_set_x"][:])
test_set_y = np.array(test_dataset["test_set_y"][:])

# Acerta dimensões das saídas
train_set_y = train_set_y.reshape((1, train_set_y.shape[0]))
test_set_y = test_set_y.reshape((1, test_set_y.shape[0]))

classes = np.array(test_dataset["list_classes"][:]) # the list of classes

# %%
# Examplo de uma imagem
index = 11
print(train_set_x_orig[index].shape)
plt.imshow(train_set_x_orig[index])
print ("y = " + str(train_set_y[:, index]) + ", it's a '" + classes[np.squeeze(train_set_y[:, index])].decode("utf-8") +  "' picture.")
# Out:
# (64, 64, 3)
# y = [1], it's a 'cat' picture.

# %% [markdown]
# No código acima index é o número sequencial da imagem. Tente trocar a imagem, mudando o index, usando valores entre 0 e 208, para visualizar outros exemplos.

# %% [markdown]
# ### 3.1 - Determinação do formato e dimensões dos dados
#
# ### Exercício #1:
#
# É importante conhecer as dimensões dos dados que estamos trabalhando para evitar problemas. Assim, obtenha os valores dos seguintes parâmetros:
#     - m_train = número de exemplos de treinamento;
#     - m_test = número de exemplos de teste;
#     - num_px = altura e largura das imagens (as imagens são quadradas).
#
# Lembre que `train_set_x_orig` é um tensor numpy de dimensão (m_train, num_px, num_px, 3). Por exemplo, você pode obter  `m_train` escrevendo `train_set_x_orig.shape[0]`.

# %%
# PARA VOCÊ FAZER:

### COMECE AQUIE ### (≈ 3 linhas)
m_train = train_set_x_orig.shape[0]
m_test = test_set_x_orig.shape[0]
num_px = train_set_x_orig.shape[1]
### TERMINE AQUI ###

print ("Número de exemplos de treinamento: m_train = " + str(m_train))
print ("Número de exemplos de teste: m_test = " + str(m_test))
print ("Altura/largura de cada imagem: num_px = " + str(num_px))
print ("Dimensão de cada imagem: (" + str(num_px) + ", " + str(num_px) + ", 3)")
print ("Dimensão - train_set_x: " + str(train_set_x_orig.shape))
print ("Dimensão - train_set_y: " + str(train_set_y.shape))
print ("Dimensão - test_set_x: " + str(test_set_x_orig.shape))
print ("Dimensão - test_set_y: " + str(test_set_y.shape))
# Out:
# Número de exemplos de treinamento: m_train = 209
# Número de exemplos de teste: m_test = 50
# Altura/largura de cada imagem: num_px = 64
# Dimensão de cada imagem: (64, 64, 3)
# Dimensão - train_set_x: (209, 64, 64, 3)
# Dimensão - train_set_y: (1, 209)
# Dimensão - test_set_x: (50, 64, 64, 3)
# Dimensão - test_set_y: (1, 50)

# %% [markdown]
# **Saída esperada para m_train, m_test e num_px**:
#
#     Número de exemplos de treinamento: m_train = 209
#     Número de exemplos de teste: m_test = 50
#     Altura/largura de cada imagem: num_px = 64
#     Dimensão de cada imagem: (64, 64, 3)
#     Dimensão - train_set_x: (209, 64, 64, 3)
#     Dimensão - train_set_y: (1, 209)
#     Dimensão - test_set_x: (50, 64, 64, 3)
#     >Dimensão - test_set_y: (1, 50)
#
# Observe que o primeiro eixo dos tensores com as imagens dos conjuntos de teste e de treinamento representa os exemplos, da forma como é esperado para os dados no Keras.

# %% [markdown]
# ### 3.2 - Processamento dos dados
#
# Os dados dos exemplos de treinamento e de teste devem ser processados de forma a serem colocados em tensores com as dimensões adequadas e normalizados corretamente. Nos exercícios que seguem você irá realizar o processamento dos dados de forma a poderem ser usados na sua RNA implementada com o Keras.

# %% [markdown]
# ### Redimensionamento dos dados
#
# Os dados de entrada de uma camada de neurônios densa é um vetor, assim, devemos redimensionar as imagens, que tem dimensão (num_px, num_px, 3), para transformá-las em um vetor linha de dimensão (1, num_px∗num_px∗3). Após esse redimensionamento o conjunto de dados é um tensor numpy onde cada linha representa uma imagem "esticada". O tensor com as entradas dos dados de treinamento terá m_train linhas e o de teste m_test linhas.
#
# Por exemplo, para redimensionar uma matriz de dimensão (a,b,c,d) para uma matriz de dimensão (a, b∗c∗d) pode-se usar o seguinte código Python:
#
#     X_flatten = X.reshape((a, b∗c∗d))
#
# A dimensão dos dados de saída também deve ser alterada porque, como visto, o Keras espara que os exemplos representam o primeiro eixo do tensor e nos dados de saída os exemplos representam o segundo eixo. Assim, os vetores com os dados de saída, tanto de treinamento como de teste, devem ser transpostos.

# %% [markdown]
# ### Exercício #2:
#
# Implemente o redimensionamento dos dados de entrada na célula a seguir.

# %%
# PARA VOCÊ FAZER: redimensionamento das imagens dos exemplos de treinamento e teste

### COMECE AQUI ### (≈ 2 linhas)
# Redimensionamento dos dados de entrada
train_set_x_flatten = train_set_x_orig.reshape((m_train, num_px * num_px * 3))
test_set_x_flatten = test_set_x_orig.reshape((m_test, num_px * num_px * 3))
### TERMINE AQUI ###

### COMECE AQUI ### (≈ 2 linhas)
# Redimensionamento dos dados de saída (transposição)
train_set_y = train_set_y.T
test_set_y = test_set_y.T
### TERMINE AQUI ###

print ("Dimensão - train_set_x_flatten: " + str(train_set_x_flatten.shape))
print ("Dimensão - train_set_y: " + str(train_set_y.shape))
print ("Dimensão - test_set_x_flatten: " + str(test_set_x_flatten.shape))
print ("Dimensão - test_set_y: " + str(test_set_y.shape))
print ("Verificação de valores após redimensionamento: " + str(train_set_x_flatten[0,0:5]))
# Out:
# Dimensão - train_set_x_flatten: (209, 12288)
# Dimensão - train_set_y: (209, 1)
# Dimensão - test_set_x_flatten: (50, 12288)
# Dimensão - test_set_y: (50, 1)
# Verificação de valores após redimensionamento: [17 31 56 22 33]

# %% [markdown]
# **Saída esperada**:
#
#     Dimensão - train_set_x_flatten: (209, 12288)
#     Dimensão - train_set_y: (209, 1)
#     Dimensão - test_set_x_flatten: (50, 12288)
#     Dimensão - test_set_y: (50, 1)
#     Verificação de valores após redimensionamento: [17 31 56 22 33]

# %% [markdown]
# ### Normalização dos dados
#
# Nas imagens coloridas as cores vermelho, verde e azul (RGB) são especificadas para cada pixel da imagem, de forma que cada pixel consite de um vetor de tres números que variam no intervalo de 0 a 255.
#
# Uma etapa do processamento dos dados é normalizar esses dados de forma a ter dados com média zero e desvio padrão um. No caso de imagens o processo de normalização dos dados é mais simples e consiste simplesmente em dividir todos os valores da imagem por 255, que é o valor máximo de um pixel.
#
# ### Exercício #3:
#
# Implemente a normalização dos dados de forma a ter todas os elementos dos dados de entrada entre 0 e 1.

# %%
# PARA VOCÊ FAZER: redimensionamento das imagens dos exemplos de treinamento e teste

### COMECE AQUI ### (≈ 2 linhas)
train_set_x = train_set_x_flatten/255
test_set_x = test_set_x_flatten/255
### TERMINE AQUI ###

print ("Máximo valor de train_set_x: " + str(np.max(train_set_x)))
print ("Máximo valor de train_set_x: " + str(np.max(test_set_x)))
# Out:
# Máximo valor de train_set_x: 1.0
# Máximo valor de train_set_x: 1.0

# %% [markdown]
# **Saída esperada**:
#
#     Máximo valor de train_set_x: 1.0
#     Máximo valor de train_set_x: 1.0

# %% [markdown]
# <font color='blue'>
#
# **O que é importante lembrar:**
#
# As etapas principais do processamento de dados são as seguintes:
# - Verificar a dimensão e formato dos dados do problema. Nesse caso são: m_train, m_test, num_px, ...
# - Redimensionar os conjuntos de dados. Nesse caso para cada exemplo a entrada é um vetor linha de dimensão (1, num_px \* num_px \* 3)
# - Normalizar os dados

# %% [markdown]
# ## 4 - Desenvolvimento e teste da rede neural rasa
#
# Nesse trabalho vamos testar diferentes redes neurais, variando numero de camadas, numero de neurônios nas camadas e tipo de função de ativação para obtermos uma solução que apresente resultados satisfatórios.
#
# Conforme vimos em aula, o desenvolvimento de uma RNA com o Keras é feito segundo as seguintes etapas:
#
# 1. Definição dos dados de treinamento e de teste;
# 2. Configuração da RNA;
# 3. Compilação da RNA, que também inclui a configuração do processo de treinamento pela escolha da função de custo, do otimizador e da métrica para avaliar o desempenho;
# 4. Treinamento da RNA;
# 5. Teste e avaliação do desempenho da RNA.
#
# Observe que a etapa de definição e preparação dos dados já foi realizada.

# %% [markdown]
# ### 4.1 - Configuração da rede neural ##
#
# Vamos configurar, treinar e testar uma primeira rede neural simples de uma camada intermediária usando o Keras.
#
# Para essa rede de uma camada, o parâmetro mais importante é o número de neurônios da camada intermediária. Esse número deve ser compatível com o problema que queremos resolver e também com o número de exemplos que temos disponíveis para treinar a rede.
#
# Em linhas gerais cada imagem é representada por 12.288 números e temos 209 imagens de treinamento. Assim, no conjunto de dados de treinamento temos cerca de 2,6 milhões de valores. Existem um princípio em aprendizado supervisionado que diz que o número de parâmetros do sistema deve ser menor do que o número de valores presente no conjunto de dados utilizado para o treinamento. Assim, a sua rede neural deve ter um número de parâmetros menor do que 2,6 milhões. Se a rede possuir mais parâmetros do que o número de valores presentes no conjunto de dados, ela simplesmente memoriza os dados de treinamento e não funciona direito para nenhum outro caso.
#
# **Qualquer dúvida que você possa ter de como fazer esse trabalho usando o Keras, consulte os slides e o notebook da aula no Moodle**
#
# ### Exercício #4:
#
# Usando o Keras configure uma rede neural com as seguintes caracteríticas:
#
# - uma única camada intermediária com 64 neurônios e função de ativação sigmóide;
# - como queremos resolver um problema de classificação binária a camada de saída deve possuir um único neurônio e ter função de ativação sigmóide.

# %%
# PARA VOCÊ FAZER: configuração de uma RNA rasa

# Importar do Keras classes de modelos e camadas
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation

np.random.seed(1) # inicializa gerador de números aleatórios

# Configuração da rede
### COMECE AQUI ### (≈ 3 linhas)
rna = Sequential()
rna.add(Dense(64, activation='sigmoid', input_shape=(12288,)))
rna.add(Dense(1, activation='sigmoid'))
### TERMINE AQUI ###

# Visualização da rede
rna.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_4 (Dense)                      │ (None, 64)                  │         786,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_5 (Dense)                      │ (None, 1)                   │              65 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 786,561 (3.00 MB)
#  Trainable params: 786,561 (3.00 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# **Saída esperada:**
#
#     Model: "sequential"
#     _________________________________________________________________
#     Layer (type)                 Output Shape              Param #
#     =================================================================
#     dense (Dense)                (None, 64)                786496
#     _________________________________________________________________
#     dense_1 (Dense)              (None, 1)                 65
#     =================================================================
#     Total params: 786,561
#     Trainable params: 786,561
#     Non-trainable params: 0
#     _________________________________________________________________

# %% [markdown]
# ### 4.2 - Compilação e treinamento da rede neural
#
# A segunda e terceira etapas de desenvolvimento da rede no Keras é a sua compilação e treinamento.
#
# ### Exercício #5:
#
# Compile e treine a sua rede neural usando as seguintes opções:
#
# - Método de otimização: gradiente descendente;
# - Função de custo: entropia cruzada;
# - Métrica: exatidão;
# - No treinamento, utilize no método fit o parâmetro batch_size=209, que é o número de exemplos de treinamento;
# - Número de épocas: 10.
#
# Nesse momento estamos treinando a rede somente para verificar se ela é adequada para resolver o problema e se está configurada de forma correta, por isso usamos poucas épocas de treinamento.
#
# Note que para o Keras, certos parâmetros podem ser definidos de formas distintas. Por exemplo, a métrica "Mean Absolute Error" pode ser definida como keras.metrics.MeanAbsoluteError() ou simplesmente pelo string 'mae'.

# %%
# PARA VOCÊ FAZER: configuração do otimizador e treinamento da RNA rasa

# Importar do Keras classe de otimizadores
from tensorflow.keras import optimizers
from tensorflow.keras import losses
from tensorflow.keras import metrics

# Compilação da rede
### COMECE AQUI ### (≈ 1 ou 2 linhas)
rna.compile(optimizer=optimizers.SGD(), loss='binary_crossentropy', metrics=['accuracy'])
### TERMINE AQUI ###

# Teste de treinamento da rede
### COMECE AQUI ### (≈ 1 linha)
rna.fit(train_set_x, train_set_y, epochs=10, batch_size=209)
### TERMINE AQUI ###
# Out:
# Epoch 1/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - accuracy: 0.6555 - loss: 0.6427
# Epoch 2/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.6555 - loss: 0.6418
# Epoch 3/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.6555 - loss: 0.6411
# Epoch 4/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.6555 - loss: 0.6403
# Epoch 5/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.6555 - loss: 0.6395
# Epoch 6/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.6555 - loss: 0.6387
# Epoch 7/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.6555 - loss: 0.6380
# Epoch 8/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.6555 - loss: 0.6372
# Epoch 9/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.6555 - loss: 0.6364
# Epoch 10/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.6555 - loss: 0.6357

# %% [markdown]
# **Saída esperada:**
#
#     Epoch 1/10
#     209/209 [==============================] - 0s 1ms/sample - loss: 0.7257 - acc: 0.3876
#     Epoch 2/10
#     209/209 [==============================] - 0s 272us/sample - loss: 0.6633 - acc: 0.6555
#     Epoch 3/10
#     209/209 [==============================] - 0s 162us/sample - loss: 0.6539 - acc: 0.6459
#     Epoch 4/10
#     209/209 [==============================] - 0s 153us/sample - loss: 0.6515 - acc: 0.6507
#     Epoch 5/10
#     209/209 [==============================] - 0s 153us/sample - loss: 0.6502 - acc: 0.6507
#     Epoch 6/10
#     209/209 [==============================] - 0s 143us/sample - loss: 0.6491 - acc: 0.6507
#     Epoch 7/10
#     209/209 [==============================] - 0s 153us/sample - loss: 0.6481 - acc: 0.6507
#     Epoch 8/10
#     209/209 [==============================] - 0s 166us/sample - loss: 0.6471 - acc: 0.6507
#     Epoch 9/10
#     209/209 [==============================] - 0s 157us/sample - loss: 0.6461 - acc: 0.6507
#     Epoch 10/10
#     209/209 [==============================] - 0s 167us/sample - loss: 0.6451 - acc: 0.6507
#
# Se o seu resultado é esse ou parecido com esse, você pode conluir que a rede está correta e é capaz de aprender os dados de treinamento. Assim, agora você está pronto para treinar a rede de verdade.
#
# Atenção: É normal que os valores sejam ligeiramente diferentes nesta etapa. Mesmo com seeds aleatórios fixos, algumas etapas do treinamento podem não ser completamente determinísticas.

# %% [markdown]
# ### Exercício #6:
#
# Retreine a sua rede usando 1000 épocas.
#
# Use a opção de **não imprimir** os resultados parciais do treinamento para não gerar tantos dados. No Keras podemos escolher como monitoramos o progresso do treinamento com o parâmetro verbose do método fit, que nos dá as seguintes opções:
#
# - verbose: inteiro = 0, 1, or 2.
# - verbose = 0: silencioso;
# - verbose = 1; barra de progresso (padrão);
# - verbose = 2; uma linha por época.
#
# Guarde os resultados do treinamento para poder fazer um gráfico do processo de treinamento. Se tiver dúvidas, veja no notebook desenvolvido em aula como fazer isso.
#
# Não se esqueça de usar no método fit o parâmetro batch_size=209.
#
# Esse treinamento pode levar alguns minutos. No Google Colab levou cerca de 30 segundossem uso de GPU, mas pode variar dependendo de detalhes da implementação e da carga nos servidores do Colab

# %%
# PARA VOCÊ FAZER: treinamento da RNA por 1000 épocas

### COMECE AQUI ### (≈ 1 linha)
history = rna.fit(train_set_x, train_set_y, epochs=1000, batch_size=209, verbose=1)
### TERMINE AQUI ###
# Out:
# Epoch 1/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.8230 - loss: 0.4354
# Epoch 2/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.8230 - loss: 0.4351
# Epoch 3/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.8230 - loss: 0.4349
# Epoch 4/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.8230 - loss: 0.4346
# Epoch 5/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.8230 - loss: 0.4343
# Epoch 6/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.8230 - loss: 0.4341
# Epoch 7/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.8230 - loss: 0.4338
# Epoch 8/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.8230 - loss: 0.4336
# Epoch 9/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.8230 - loss: 0.4333
# Epoch 10/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.8230 - loss: 0.4330
# Epoch 11/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.8230 - loss: 0.4328
# Epoch 12/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.8230 - loss: 0.4325
# Epoch 13/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.8230 - loss: 0.4322
# Epoch 14/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.8230 - loss: 0.4320
# Epoch 15/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.8278 - loss: 0.4317
# Epoch 16/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.8278 - loss: 0.4314
# Epoch 17/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.8278 - loss: 0.4312
# Epoch 18/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.8278 - loss: 0.4309
# Epoch 19/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.8278 - loss: 0.4307
# Epoch 20/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.8278 - loss: 0.4304
# Epoch 21/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.8278 - loss: 0.4301
# Epoch 22/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.8278 - loss: 0.4299
# Epoch 23/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.8278 - loss: 0.4296
# Epoch 24/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.8278 - loss: 0.4293
# Epoch 25/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.8278 - loss: 0.4291
# Epoch 26/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.8278 - loss: 0.4288
# Epoch 27/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.8278 - loss: 0.4286
# Epoch 28/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.8325 - loss: 0.4283
# Epoch 29/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.8325 - loss: 0.4280
# Epoch 30/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.8325 - loss: 0.4278
# Epoch 31/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.8325 - loss: 0.4275
# Epoch 32/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.8325 - loss: 0.4272
# Epoch 33/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.8325 - loss: 0.4270
# Epoch 34/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.8325 - loss: 0.4267
# Epoch 35/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.8325 - loss: 0.4265
# Epoch 36/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.8325 - loss: 0.4262
# Epoch 37/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.8325 - loss: 0.4259
# Epoch 38/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.8325 - loss: 0.4257
# Epoch 39/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.8325 - loss: 0.4254
# Epoch 40/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.8325 - loss: 0.4252
# Epoch 41/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.8373 - loss: 0.4249
# Epoch 42/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.8373 - loss: 0.4246
# Epoch 43/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.8373 - loss: 0.4244
# Epoch 44/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.8373 - loss: 0.4241
# Epoch 45/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.8373 - loss: 0.4239
# Epoch 46/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.8373 - loss: 0.4236
# Epoch 47/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.8373 - loss: 0.4233
# Epoch 48/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.8373 - loss: 0.4231
# Epoch 49/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.8373 - loss: 0.4228
# Epoch 50/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.8373 - loss: 0.4226
# Epoch 51/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.8373 - loss: 0.4223
# Epoch 52/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.8373 - loss: 0.4220
# Epoch 53/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.8373 - loss: 0.4218
# Epoch 54/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.8373 - loss: 0.4215
# Epoch 55/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.8373 - loss: 0.4213
# Epoch 56/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.8421 - loss: 0.4210
# Epoch 57/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.8421 - loss: 0.4208
# Epoch 58/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.8421 - loss: 0.4205
# Epoch 59/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.8421 - loss: 0.4202
# Epoch 60/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.8421 - loss: 0.4200
# Epoch 61/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.8421 - loss: 0.4197
# Epoch 62/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.8421 - loss: 0.4195
# Epoch 63/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.8421 - loss: 0.4192
# Epoch 64/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.8421 - loss: 0.4189
# Epoch 65/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.8421 - loss: 0.4187
# Epoch 66/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.8421 - loss: 0.4184
# Epoch 67/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.8421 - loss: 0.4182
# Epoch 68/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.8421 - loss: 0.4179
# Epoch 69/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.8421 - loss: 0.4177
# Epoch 70/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.8421 - loss: 0.4174
# Epoch 71/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.8421 - loss: 0.4171
# Epoch 72/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.8421 - loss: 0.4169
# Epoch 73/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.8421 - loss: 0.4166
# Epoch 74/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.8421 - loss: 0.4164
# Epoch 75/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.8421 - loss: 0.4161
# Epoch 76/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.8421 - loss: 0.4159
# Epoch 77/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.8421 - loss: 0.4156
# Epoch 78/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.8421 - loss: 0.4154
# Epoch 79/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.8421 - loss: 0.4151
# Epoch 80/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.8421 - loss: 0.4148
# Epoch 81/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 0.8421 - loss: 0.4146
# Epoch 82/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.8421 - loss: 0.4143
# Epoch 83/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.8421 - loss: 0.4141
# Epoch 84/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.8421 - loss: 0.4138
# Epoch 85/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.8421 - loss: 0.4136
# Epoch 86/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - accuracy: 0.8421 - loss: 0.4133
# Epoch 87/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.8421 - loss: 0.4131
# Epoch 88/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.8469 - loss: 0.4128
# Epoch 89/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.8469 - loss: 0.4125
# Epoch 90/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.8469 - loss: 0.4123
# Epoch 91/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.8469 - loss: 0.4120
# Epoch 92/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.8469 - loss: 0.4118
# Epoch 93/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.8565 - loss: 0.4115
# Epoch 94/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.8565 - loss: 0.4113
# Epoch 95/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.8565 - loss: 0.4110
# Epoch 96/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.8565 - loss: 0.4108
# Epoch 97/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.8565 - loss: 0.4105
# Epoch 98/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.8565 - loss: 0.4103
# Epoch 99/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.8565 - loss: 0.4100
# Epoch 100/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.8565 - loss: 0.4097
# Epoch 101/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.8565 - loss: 0.4095
# Epoch 102/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.8565 - loss: 0.4092
# Epoch 103/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.8565 - loss: 0.4090
# Epoch 104/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.8565 - loss: 0.4087
# Epoch 105/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.8565 - loss: 0.4085
# Epoch 106/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.8565 - loss: 0.4082
# Epoch 107/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.8565 - loss: 0.4080
# Epoch 108/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 0.8565 - loss: 0.4077
# Epoch 109/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.8565 - loss: 0.4075
# Epoch 110/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.8612 - loss: 0.4072
# Epoch 111/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.8612 - loss: 0.4070
# Epoch 112/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.8612 - loss: 0.4067
# Epoch 113/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.8612 - loss: 0.4065
# Epoch 114/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.8612 - loss: 0.4062
# Epoch 115/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.8612 - loss: 0.4060
# Epoch 116/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 0.8612 - loss: 0.4057
# Epoch 117/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.8612 - loss: 0.4055
# Epoch 118/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.8612 - loss: 0.4052
# Epoch 119/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.8612 - loss: 0.4050
# Epoch 120/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.8612 - loss: 0.4047
# Epoch 121/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.8612 - loss: 0.4045
# Epoch 122/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.8612 - loss: 0.4042
# Epoch 123/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - accuracy: 0.8612 - loss: 0.4039
# Epoch 124/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.8612 - loss: 0.4037
# Epoch 125/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.8612 - loss: 0.4034
# Epoch 126/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.8612 - loss: 0.4032
# Epoch 127/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.8612 - loss: 0.4029
# Epoch 128/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.8612 - loss: 0.4027
# Epoch 129/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.8612 - loss: 0.4024
# Epoch 130/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.8612 - loss: 0.4022
# Epoch 131/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.8612 - loss: 0.4019
# Epoch 132/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.8612 - loss: 0.4017
# Epoch 133/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.8612 - loss: 0.4014
# Epoch 134/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.8612 - loss: 0.4012
# Epoch 135/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.8612 - loss: 0.4009
# Epoch 136/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.8612 - loss: 0.4007
# Epoch 137/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.8612 - loss: 0.4004
# Epoch 138/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.8612 - loss: 0.4002
# Epoch 139/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.8612 - loss: 0.3999
# Epoch 140/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.8660 - loss: 0.3997
# Epoch 141/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.8660 - loss: 0.3994
# Epoch 142/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.8660 - loss: 0.3992
# Epoch 143/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.8660 - loss: 0.3990
# Epoch 144/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.8660 - loss: 0.3987
# Epoch 145/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.8660 - loss: 0.3985
# Epoch 146/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.8660 - loss: 0.3982
# Epoch 147/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.8660 - loss: 0.3980
# Epoch 148/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.8660 - loss: 0.3977
# Epoch 149/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.8660 - loss: 0.3975
# Epoch 150/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.8660 - loss: 0.3972
# Epoch 151/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.8660 - loss: 0.3970
# Epoch 152/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.8708 - loss: 0.3967
# Epoch 153/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.8708 - loss: 0.3965
# Epoch 154/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.8708 - loss: 0.3962
# Epoch 155/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.8708 - loss: 0.3960
# Epoch 156/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.8708 - loss: 0.3957
# Epoch 157/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.8708 - loss: 0.3955
# Epoch 158/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.8708 - loss: 0.3952
# Epoch 159/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.8708 - loss: 0.3950
# Epoch 160/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.8708 - loss: 0.3947
# Epoch 161/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.8708 - loss: 0.3945
# Epoch 162/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.8708 - loss: 0.3942
# Epoch 163/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.8708 - loss: 0.3940
# Epoch 164/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.8708 - loss: 0.3937
# Epoch 165/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.8756 - loss: 0.3935
# Epoch 166/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.8756 - loss: 0.3933
# Epoch 167/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.8756 - loss: 0.3930
# Epoch 168/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.8756 - loss: 0.3928
# Epoch 169/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.8756 - loss: 0.3925
# Epoch 170/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.8756 - loss: 0.3923
# Epoch 171/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.8756 - loss: 0.3920
# Epoch 172/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.8756 - loss: 0.3918
# Epoch 173/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.8756 - loss: 0.3915
# Epoch 174/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.8756 - loss: 0.3913
# Epoch 175/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.8756 - loss: 0.3910
# Epoch 176/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.8804 - loss: 0.3908
# Epoch 177/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.8804 - loss: 0.3906
# Epoch 178/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.8804 - loss: 0.3903
# Epoch 179/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.8804 - loss: 0.3901
# Epoch 180/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.8804 - loss: 0.3898
# Epoch 181/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.8804 - loss: 0.3896
# Epoch 182/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.8804 - loss: 0.3893
# Epoch 183/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.8804 - loss: 0.3891
# Epoch 184/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.8804 - loss: 0.3888
# Epoch 185/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.8804 - loss: 0.3886
# Epoch 186/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.8804 - loss: 0.3884
# Epoch 187/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.8804 - loss: 0.3881
# Epoch 188/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.8804 - loss: 0.3879
# Epoch 189/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.8804 - loss: 0.3876
# Epoch 190/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.8804 - loss: 0.3874
# Epoch 191/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.8804 - loss: 0.3871
# Epoch 192/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.8804 - loss: 0.3869
# Epoch 193/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.8804 - loss: 0.3866
# Epoch 194/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.8804 - loss: 0.3864
# Epoch 195/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.8804 - loss: 0.3862
# Epoch 196/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.8804 - loss: 0.3859
# Epoch 197/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.8804 - loss: 0.3857
# Epoch 198/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.8804 - loss: 0.3854
# Epoch 199/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.8804 - loss: 0.3852
# Epoch 200/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.8804 - loss: 0.3849
# Epoch 201/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.8804 - loss: 0.3847
# Epoch 202/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.8804 - loss: 0.3845
# Epoch 203/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.8804 - loss: 0.3842
# Epoch 204/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.8804 - loss: 0.3840
# Epoch 205/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.8804 - loss: 0.3837
# Epoch 206/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.8804 - loss: 0.3835
# Epoch 207/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.8804 - loss: 0.3832
# Epoch 208/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.8804 - loss: 0.3830
# Epoch 209/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.8804 - loss: 0.3828
# Epoch 210/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.8804 - loss: 0.3825
# Epoch 211/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.8804 - loss: 0.3823
# Epoch 212/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.8804 - loss: 0.3820
# Epoch 213/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.8804 - loss: 0.3818
# Epoch 214/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.8804 - loss: 0.3816
# Epoch 215/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.8804 - loss: 0.3813
# Epoch 216/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.8804 - loss: 0.3811
# Epoch 217/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.8804 - loss: 0.3808
# Epoch 218/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.8804 - loss: 0.3806
# Epoch 219/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.8804 - loss: 0.3804
# Epoch 220/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.8804 - loss: 0.3801
# Epoch 221/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.8804 - loss: 0.3799
# Epoch 222/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.8852 - loss: 0.3796
# Epoch 223/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.8852 - loss: 0.3794
# Epoch 224/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.8852 - loss: 0.3792
# Epoch 225/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.8852 - loss: 0.3789
# Epoch 226/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.8852 - loss: 0.3787
# Epoch 227/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.8852 - loss: 0.3784
# Epoch 228/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.8852 - loss: 0.3782
# Epoch 229/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.8852 - loss: 0.3780
# Epoch 230/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.8852 - loss: 0.3777
# Epoch 231/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.8852 - loss: 0.3775
# Epoch 232/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.8852 - loss: 0.3772
# Epoch 233/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.8852 - loss: 0.3770
# Epoch 234/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.8852 - loss: 0.3768
# Epoch 235/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.8852 - loss: 0.3765
# Epoch 236/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.8852 - loss: 0.3763
# Epoch 237/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.8852 - loss: 0.3760
# Epoch 238/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.8852 - loss: 0.3758
# Epoch 239/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.8852 - loss: 0.3756
# Epoch 240/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.8852 - loss: 0.3753
# Epoch 241/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.8852 - loss: 0.3751
# Epoch 242/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.8852 - loss: 0.3748
# Epoch 243/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.8852 - loss: 0.3746
# Epoch 244/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.8852 - loss: 0.3744
# Epoch 245/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.8852 - loss: 0.3741
# Epoch 246/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.8852 - loss: 0.3739
# Epoch 247/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.8852 - loss: 0.3737
# Epoch 248/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.8852 - loss: 0.3734
# Epoch 249/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.8852 - loss: 0.3732
# Epoch 250/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.8900 - loss: 0.3729
# Epoch 251/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.8900 - loss: 0.3727
# Epoch 252/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.8900 - loss: 0.3725
# Epoch 253/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.8900 - loss: 0.3722
# Epoch 254/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.8900 - loss: 0.3720
# Epoch 255/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.8900 - loss: 0.3718
# Epoch 256/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.8900 - loss: 0.3715
# Epoch 257/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.8900 - loss: 0.3713
# Epoch 258/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.8900 - loss: 0.3711
# Epoch 259/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.8900 - loss: 0.3708
# Epoch 260/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.8900 - loss: 0.3706
# Epoch 261/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.8900 - loss: 0.3703
# Epoch 262/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.8900 - loss: 0.3701
# Epoch 263/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.8900 - loss: 0.3699
# Epoch 264/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.8900 - loss: 0.3696
# Epoch 265/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.8900 - loss: 0.3694
# Epoch 266/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.8900 - loss: 0.3692
# Epoch 267/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.8900 - loss: 0.3689
# Epoch 268/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.8900 - loss: 0.3687
# Epoch 269/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.8900 - loss: 0.3685
# Epoch 270/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.8900 - loss: 0.3682
# Epoch 271/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.8900 - loss: 0.3680
# Epoch 272/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.8900 - loss: 0.3678
# Epoch 273/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.8900 - loss: 0.3675
# Epoch 274/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.8900 - loss: 0.3673
# Epoch 275/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.8900 - loss: 0.3670
# Epoch 276/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.8900 - loss: 0.3668
# Epoch 277/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.8900 - loss: 0.3666
# Epoch 278/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.8900 - loss: 0.3663
# Epoch 279/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.8900 - loss: 0.3661
# Epoch 280/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.8900 - loss: 0.3659
# Epoch 281/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.8900 - loss: 0.3656
# Epoch 282/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.8900 - loss: 0.3654
# Epoch 283/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.8900 - loss: 0.3652
# Epoch 284/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.8900 - loss: 0.3649
# Epoch 285/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.8900 - loss: 0.3647
# Epoch 286/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.8900 - loss: 0.3645
# Epoch 287/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.8900 - loss: 0.3642
# Epoch 288/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.8900 - loss: 0.3640
# Epoch 289/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.8900 - loss: 0.3638
# Epoch 290/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.8900 - loss: 0.3635
# Epoch 291/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.8900 - loss: 0.3633
# Epoch 292/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.8900 - loss: 0.3631
# Epoch 293/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.8900 - loss: 0.3628
# Epoch 294/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.8900 - loss: 0.3626
# Epoch 295/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.8900 - loss: 0.3624
# Epoch 296/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.8900 - loss: 0.3621
# Epoch 297/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.8900 - loss: 0.3619
# Epoch 298/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.8900 - loss: 0.3617
# Epoch 299/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.8900 - loss: 0.3614
# Epoch 300/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.8900 - loss: 0.3612
# Epoch 301/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.8900 - loss: 0.3610
# Epoch 302/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.8900 - loss: 0.3608
# Epoch 303/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.8900 - loss: 0.3605
# Epoch 304/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.8900 - loss: 0.3603
# Epoch 305/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.8900 - loss: 0.3601
# Epoch 306/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.8900 - loss: 0.3598
# Epoch 307/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.8900 - loss: 0.3596
# Epoch 308/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.8900 - loss: 0.3594
# Epoch 309/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.8900 - loss: 0.3591
# Epoch 310/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.8900 - loss: 0.3589
# Epoch 311/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.8900 - loss: 0.3587
# Epoch 312/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.8900 - loss: 0.3584
# Epoch 313/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.8900 - loss: 0.3582
# Epoch 314/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.8900 - loss: 0.3580
# Epoch 315/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.8900 - loss: 0.3577
# Epoch 316/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.8900 - loss: 0.3575
# Epoch 317/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.8900 - loss: 0.3573
# Epoch 318/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.8900 - loss: 0.3571
# Epoch 319/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.8900 - loss: 0.3568
# Epoch 320/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.8900 - loss: 0.3566
# Epoch 321/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.8900 - loss: 0.3564
# Epoch 322/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.8900 - loss: 0.3561
# Epoch 323/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.8900 - loss: 0.3559
# Epoch 324/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - accuracy: 0.8947 - loss: 0.3557
# Epoch 325/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.8947 - loss: 0.3554
# Epoch 326/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.8947 - loss: 0.3552
# Epoch 327/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.8947 - loss: 0.3550
# Epoch 328/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.8947 - loss: 0.3548
# Epoch 329/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.8947 - loss: 0.3545
# Epoch 330/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 0.8947 - loss: 0.3543
# Epoch 331/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.8947 - loss: 0.3541
# Epoch 332/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.8947 - loss: 0.3538
# Epoch 333/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.8947 - loss: 0.3536
# Epoch 334/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.8947 - loss: 0.3534
# Epoch 335/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.8947 - loss: 0.3532
# Epoch 336/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.8947 - loss: 0.3529
# Epoch 337/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.8947 - loss: 0.3527
# Epoch 338/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.8947 - loss: 0.3525
# Epoch 339/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.8947 - loss: 0.3523
# Epoch 340/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.8947 - loss: 0.3520
# Epoch 341/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.8947 - loss: 0.3518
# Epoch 342/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.8947 - loss: 0.3516
# Epoch 343/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.8947 - loss: 0.3513
# Epoch 344/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 0.8947 - loss: 0.3511
# Epoch 345/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.8947 - loss: 0.3509
# Epoch 346/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.8947 - loss: 0.3507
# Epoch 347/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.8947 - loss: 0.3504
# Epoch 348/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - accuracy: 0.8947 - loss: 0.3502
# Epoch 349/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.8947 - loss: 0.3500
# Epoch 350/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.8947 - loss: 0.3498
# Epoch 351/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 0.8947 - loss: 0.3495
# Epoch 352/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.8947 - loss: 0.3493
# Epoch 353/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.8947 - loss: 0.3491
# Epoch 354/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.8947 - loss: 0.3488
# Epoch 355/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - accuracy: 0.8947 - loss: 0.3486
# Epoch 356/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.8947 - loss: 0.3484
# Epoch 357/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.8947 - loss: 0.3482
# Epoch 358/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - accuracy: 0.8947 - loss: 0.3479
# Epoch 359/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.8947 - loss: 0.3477
# Epoch 360/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.8947 - loss: 0.3475
# Epoch 361/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.8947 - loss: 0.3473
# Epoch 362/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.8947 - loss: 0.3470
# Epoch 363/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.8947 - loss: 0.3468
# Epoch 364/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.8995 - loss: 0.3466
# Epoch 365/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.8995 - loss: 0.3464
# Epoch 366/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.8995 - loss: 0.3461
# Epoch 367/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.8995 - loss: 0.3459
# Epoch 368/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.8995 - loss: 0.3457
# Epoch 369/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.8995 - loss: 0.3455
# Epoch 370/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.8995 - loss: 0.3452
# Epoch 371/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.8995 - loss: 0.3450
# Epoch 372/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.8995 - loss: 0.3448
# Epoch 373/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.8995 - loss: 0.3446
# Epoch 374/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.8995 - loss: 0.3443
# Epoch 375/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.8995 - loss: 0.3441
# Epoch 376/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.8995 - loss: 0.3439
# Epoch 377/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.8995 - loss: 0.3437
# Epoch 378/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.8995 - loss: 0.3435
# Epoch 379/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.8995 - loss: 0.3432
# Epoch 380/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.8995 - loss: 0.3430
# Epoch 381/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.8995 - loss: 0.3428
# Epoch 382/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.8995 - loss: 0.3426
# Epoch 383/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.8995 - loss: 0.3423
# Epoch 384/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9043 - loss: 0.3421
# Epoch 385/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.9043 - loss: 0.3419
# Epoch 386/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9043 - loss: 0.3417
# Epoch 387/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9043 - loss: 0.3414
# Epoch 388/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9043 - loss: 0.3412
# Epoch 389/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.9043 - loss: 0.3410
# Epoch 390/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.9043 - loss: 0.3408
# Epoch 391/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.9043 - loss: 0.3406
# Epoch 392/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.9043 - loss: 0.3403
# Epoch 393/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.9043 - loss: 0.3401
# Epoch 394/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.9043 - loss: 0.3399
# Epoch 395/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9043 - loss: 0.3397
# Epoch 396/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.9043 - loss: 0.3394
# Epoch 397/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9043 - loss: 0.3392
# Epoch 398/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9043 - loss: 0.3390
# Epoch 399/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9043 - loss: 0.3388
# Epoch 400/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9043 - loss: 0.3386
# Epoch 401/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9043 - loss: 0.3383
# Epoch 402/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.9043 - loss: 0.3381
# Epoch 403/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.9043 - loss: 0.3379
# Epoch 404/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.9043 - loss: 0.3377
# Epoch 405/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.9043 - loss: 0.3375
# Epoch 406/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9043 - loss: 0.3372
# Epoch 407/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9043 - loss: 0.3370
# Epoch 408/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.9043 - loss: 0.3368
# Epoch 409/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.9043 - loss: 0.3366
# Epoch 410/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9043 - loss: 0.3364
# Epoch 411/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.9043 - loss: 0.3361
# Epoch 412/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.9043 - loss: 0.3359
# Epoch 413/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9043 - loss: 0.3357
# Epoch 414/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.9043 - loss: 0.3355
# Epoch 415/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9043 - loss: 0.3353
# Epoch 416/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.9043 - loss: 0.3350
# Epoch 417/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.9043 - loss: 0.3348
# Epoch 418/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.9043 - loss: 0.3346
# Epoch 419/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.9043 - loss: 0.3344
# Epoch 420/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9043 - loss: 0.3342
# Epoch 421/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.9043 - loss: 0.3339
# Epoch 422/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.9043 - loss: 0.3337
# Epoch 423/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9043 - loss: 0.3335
# Epoch 424/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.9043 - loss: 0.3333
# Epoch 425/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.9043 - loss: 0.3331
# Epoch 426/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9043 - loss: 0.3329
# Epoch 427/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.9043 - loss: 0.3326
# Epoch 428/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.9043 - loss: 0.3324
# Epoch 429/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9043 - loss: 0.3322
# Epoch 430/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9043 - loss: 0.3320
# Epoch 431/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9043 - loss: 0.3318
# Epoch 432/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.9043 - loss: 0.3315
# Epoch 433/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.9043 - loss: 0.3313
# Epoch 434/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.9043 - loss: 0.3311
# Epoch 435/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9043 - loss: 0.3309
# Epoch 436/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9043 - loss: 0.3307
# Epoch 437/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9043 - loss: 0.3305
# Epoch 438/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9043 - loss: 0.3302
# Epoch 439/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9043 - loss: 0.3300
# Epoch 440/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9043 - loss: 0.3298
# Epoch 441/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9043 - loss: 0.3296
# Epoch 442/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9043 - loss: 0.3294
# Epoch 443/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.9043 - loss: 0.3292
# Epoch 444/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.9043 - loss: 0.3289
# Epoch 445/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.9043 - loss: 0.3287
# Epoch 446/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9043 - loss: 0.3285
# Epoch 447/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.9043 - loss: 0.3283
# Epoch 448/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.9043 - loss: 0.3281
# Epoch 449/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9043 - loss: 0.3279
# Epoch 450/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9043 - loss: 0.3276
# Epoch 451/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9043 - loss: 0.3274
# Epoch 452/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9043 - loss: 0.3272
# Epoch 453/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.9043 - loss: 0.3270
# Epoch 454/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9043 - loss: 0.3268
# Epoch 455/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9043 - loss: 0.3266
# Epoch 456/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9043 - loss: 0.3264
# Epoch 457/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.9043 - loss: 0.3261
# Epoch 458/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9043 - loss: 0.3259
# Epoch 459/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.9043 - loss: 0.3257
# Epoch 460/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9043 - loss: 0.3255
# Epoch 461/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.9043 - loss: 0.3253
# Epoch 462/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.9043 - loss: 0.3251
# Epoch 463/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9043 - loss: 0.3249
# Epoch 464/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.9043 - loss: 0.3246
# Epoch 465/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.9043 - loss: 0.3244
# Epoch 466/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.9043 - loss: 0.3242
# Epoch 467/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9043 - loss: 0.3240
# Epoch 468/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.9043 - loss: 0.3238
# Epoch 469/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9043 - loss: 0.3236
# Epoch 470/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9043 - loss: 0.3234
# Epoch 471/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.9043 - loss: 0.3231
# Epoch 472/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9043 - loss: 0.3229
# Epoch 473/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9043 - loss: 0.3227
# Epoch 474/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.9043 - loss: 0.3225
# Epoch 475/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9043 - loss: 0.3223
# Epoch 476/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9043 - loss: 0.3221
# Epoch 477/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.9043 - loss: 0.3219
# Epoch 478/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9043 - loss: 0.3217
# Epoch 479/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9043 - loss: 0.3214
# Epoch 480/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9043 - loss: 0.3212
# Epoch 481/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.9043 - loss: 0.3210
# Epoch 482/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.9043 - loss: 0.3208
# Epoch 483/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9043 - loss: 0.3206
# Epoch 484/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9043 - loss: 0.3204
# Epoch 485/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.9043 - loss: 0.3202
# Epoch 486/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.9043 - loss: 0.3200
# Epoch 487/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9043 - loss: 0.3197
# Epoch 488/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9043 - loss: 0.3195
# Epoch 489/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.9091 - loss: 0.3193
# Epoch 490/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9091 - loss: 0.3191
# Epoch 491/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9091 - loss: 0.3189
# Epoch 492/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9091 - loss: 0.3187
# Epoch 493/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9091 - loss: 0.3185
# Epoch 494/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9091 - loss: 0.3183
# Epoch 495/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.9091 - loss: 0.3181
# Epoch 496/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9091 - loss: 0.3178
# Epoch 497/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.9091 - loss: 0.3176
# Epoch 498/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.9091 - loss: 0.3174
# Epoch 499/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9091 - loss: 0.3172
# Epoch 500/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9091 - loss: 0.3170
# Epoch 501/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.9091 - loss: 0.3168
# Epoch 502/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.9091 - loss: 0.3166
# Epoch 503/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9091 - loss: 0.3164
# Epoch 504/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9091 - loss: 0.3162
# Epoch 505/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9091 - loss: 0.3160
# Epoch 506/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.9091 - loss: 0.3157
# Epoch 507/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9091 - loss: 0.3155
# Epoch 508/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.9091 - loss: 0.3153
# Epoch 509/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9091 - loss: 0.3151
# Epoch 510/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9091 - loss: 0.3149
# Epoch 511/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9091 - loss: 0.3147
# Epoch 512/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9091 - loss: 0.3145
# Epoch 513/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9091 - loss: 0.3143
# Epoch 514/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9091 - loss: 0.3141
# Epoch 515/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.9091 - loss: 0.3139
# Epoch 516/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.9091 - loss: 0.3137
# Epoch 517/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.9091 - loss: 0.3135
# Epoch 518/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.9091 - loss: 0.3132
# Epoch 519/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.9091 - loss: 0.3130
# Epoch 520/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.9091 - loss: 0.3128
# Epoch 521/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9091 - loss: 0.3126
# Epoch 522/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.9091 - loss: 0.3124
# Epoch 523/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9091 - loss: 0.3122
# Epoch 524/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.9091 - loss: 0.3120
# Epoch 525/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.9091 - loss: 0.3118
# Epoch 526/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9091 - loss: 0.3116
# Epoch 527/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9091 - loss: 0.3114
# Epoch 528/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9139 - loss: 0.3112
# Epoch 529/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9139 - loss: 0.3110
# Epoch 530/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9139 - loss: 0.3108
# Epoch 531/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9139 - loss: 0.3105
# Epoch 532/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.9139 - loss: 0.3103
# Epoch 533/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.9139 - loss: 0.3101
# Epoch 534/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.9187 - loss: 0.3099
# Epoch 535/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.9187 - loss: 0.3097
# Epoch 536/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9187 - loss: 0.3095
# Epoch 537/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9187 - loss: 0.3093
# Epoch 538/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9187 - loss: 0.3091
# Epoch 539/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.9187 - loss: 0.3089
# Epoch 540/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.9187 - loss: 0.3087
# Epoch 541/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.9187 - loss: 0.3085
# Epoch 542/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 0.9187 - loss: 0.3083
# Epoch 543/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.9187 - loss: 0.3081
# Epoch 544/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.9234 - loss: 0.3079
# Epoch 545/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9234 - loss: 0.3077
# Epoch 546/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.9234 - loss: 0.3075
# Epoch 547/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - accuracy: 0.9234 - loss: 0.3073
# Epoch 548/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.9234 - loss: 0.3071
# Epoch 549/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.9234 - loss: 0.3068
# Epoch 550/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.9234 - loss: 0.3066
# Epoch 551/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9234 - loss: 0.3064
# Epoch 552/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.9234 - loss: 0.3062
# Epoch 553/1000
# ...
# Epoch 818/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.9474 - loss: 0.2559
# Epoch 819/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9474 - loss: 0.2557
# Epoch 820/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9474 - loss: 0.2555
# Epoch 821/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9474 - loss: 0.2553
# Epoch 822/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.9474 - loss: 0.2552
# Epoch 823/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.9474 - loss: 0.2550
# Epoch 824/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.9474 - loss: 0.2548
# Epoch 825/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9474 - loss: 0.2547
# Epoch 826/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9474 - loss: 0.2545
# Epoch 827/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9474 - loss: 0.2543
# Epoch 828/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.9474 - loss: 0.2541
# Epoch 829/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9474 - loss: 0.2540
# Epoch 830/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9522 - loss: 0.2538
# Epoch 831/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9522 - loss: 0.2536
# Epoch 832/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.9522 - loss: 0.2534
# Epoch 833/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.9522 - loss: 0.2533
# Epoch 834/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9522 - loss: 0.2531
# Epoch 835/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.9522 - loss: 0.2529
# Epoch 836/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9522 - loss: 0.2527
# Epoch 837/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.9522 - loss: 0.2526
# Epoch 838/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9522 - loss: 0.2524
# Epoch 839/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.9522 - loss: 0.2522
# Epoch 840/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9522 - loss: 0.2521
# Epoch 841/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.9522 - loss: 0.2519
# Epoch 842/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9522 - loss: 0.2517
# Epoch 843/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.9522 - loss: 0.2515
# Epoch 844/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.9522 - loss: 0.2514
# Epoch 845/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9522 - loss: 0.2512
# Epoch 846/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9522 - loss: 0.2510
# Epoch 847/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9522 - loss: 0.2509
# Epoch 848/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.9522 - loss: 0.2507
# Epoch 849/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9522 - loss: 0.2505
# Epoch 850/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.9522 - loss: 0.2503
# Epoch 851/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.9522 - loss: 0.2502
# Epoch 852/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.9522 - loss: 0.2500
# Epoch 853/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.9522 - loss: 0.2498
# Epoch 854/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9522 - loss: 0.2497
# Epoch 855/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.9522 - loss: 0.2495
# Epoch 856/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9522 - loss: 0.2493
# Epoch 857/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.9522 - loss: 0.2491
# Epoch 858/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9522 - loss: 0.2490
# Epoch 859/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9522 - loss: 0.2488
# Epoch 860/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9522 - loss: 0.2486
# Epoch 861/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9522 - loss: 0.2485
# Epoch 862/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.9522 - loss: 0.2483
# Epoch 863/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.9522 - loss: 0.2481
# Epoch 864/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9522 - loss: 0.2480
# Epoch 865/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.9522 - loss: 0.2478
# Epoch 866/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.9522 - loss: 0.2476
# Epoch 867/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9522 - loss: 0.2475
# Epoch 868/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.9522 - loss: 0.2473
# Epoch 869/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9522 - loss: 0.2471
# Epoch 870/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.9522 - loss: 0.2469
# Epoch 871/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9522 - loss: 0.2468
# Epoch 872/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9522 - loss: 0.2466
# Epoch 873/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.9522 - loss: 0.2464
# Epoch 874/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.9522 - loss: 0.2463
# Epoch 875/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9522 - loss: 0.2461
# Epoch 876/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.9522 - loss: 0.2459
# Epoch 877/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9522 - loss: 0.2458
# Epoch 878/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9522 - loss: 0.2456
# Epoch 879/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9522 - loss: 0.2454
# Epoch 880/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.9522 - loss: 0.2453
# Epoch 881/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.9522 - loss: 0.2451
# Epoch 882/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9522 - loss: 0.2449
# Epoch 883/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.9522 - loss: 0.2448
# Epoch 884/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9522 - loss: 0.2446
# Epoch 885/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9522 - loss: 0.2444
# Epoch 886/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.9522 - loss: 0.2443
# Epoch 887/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9522 - loss: 0.2441
# Epoch 888/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.9522 - loss: 0.2439
# Epoch 889/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.9522 - loss: 0.2438
# Epoch 890/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.9522 - loss: 0.2436
# Epoch 891/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9522 - loss: 0.2434
# Epoch 892/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.9522 - loss: 0.2433
# Epoch 893/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9522 - loss: 0.2431
# Epoch 894/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.9522 - loss: 0.2429
# Epoch 895/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.9522 - loss: 0.2428
# Epoch 896/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.9522 - loss: 0.2426
# Epoch 897/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.9522 - loss: 0.2424
# Epoch 898/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.9522 - loss: 0.2423
# Epoch 899/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.9522 - loss: 0.2421
# Epoch 900/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9522 - loss: 0.2419
# Epoch 901/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9522 - loss: 0.2418
# Epoch 902/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9522 - loss: 0.2416
# Epoch 903/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.9522 - loss: 0.2414
# Epoch 904/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.9522 - loss: 0.2413
# Epoch 905/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.9522 - loss: 0.2411
# Epoch 906/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.9522 - loss: 0.2409
# Epoch 907/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.9522 - loss: 0.2408
# Epoch 908/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9522 - loss: 0.2406
# Epoch 909/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.9522 - loss: 0.2404
# Epoch 910/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.9522 - loss: 0.2403
# Epoch 911/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.9522 - loss: 0.2401
# Epoch 912/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.9522 - loss: 0.2400
# Epoch 913/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.9522 - loss: 0.2398
# Epoch 914/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.9522 - loss: 0.2396
# Epoch 915/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.9522 - loss: 0.2395
# Epoch 916/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9522 - loss: 0.2393
# Epoch 917/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.9522 - loss: 0.2391
# Epoch 918/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9522 - loss: 0.2390
# Epoch 919/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.9522 - loss: 0.2388
# Epoch 920/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9522 - loss: 0.2386
# Epoch 921/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9522 - loss: 0.2385
# Epoch 922/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.9522 - loss: 0.2383
# Epoch 923/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.9522 - loss: 0.2382
# Epoch 924/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9522 - loss: 0.2380
# Epoch 925/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9522 - loss: 0.2378
# Epoch 926/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.9522 - loss: 0.2377
# Epoch 927/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.9522 - loss: 0.2375
# Epoch 928/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.9522 - loss: 0.2373
# Epoch 929/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9522 - loss: 0.2372
# Epoch 930/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.9522 - loss: 0.2370
# Epoch 931/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.9522 - loss: 0.2369
# Epoch 932/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9522 - loss: 0.2367
# Epoch 933/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.9522 - loss: 0.2365
# Epoch 934/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.9522 - loss: 0.2364
# Epoch 935/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.9522 - loss: 0.2362
# Epoch 936/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9522 - loss: 0.2360
# Epoch 937/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.9569 - loss: 0.2359
# Epoch 938/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9569 - loss: 0.2357
# Epoch 939/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9569 - loss: 0.2356
# Epoch 940/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.9569 - loss: 0.2354
# Epoch 941/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9569 - loss: 0.2352
# Epoch 942/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.9569 - loss: 0.2351
# Epoch 943/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9569 - loss: 0.2349
# Epoch 944/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.9569 - loss: 0.2348
# Epoch 945/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.9569 - loss: 0.2346
# Epoch 946/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.9569 - loss: 0.2344
# Epoch 947/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.9569 - loss: 0.2343
# Epoch 948/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9569 - loss: 0.2341
# Epoch 949/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9569 - loss: 0.2340
# Epoch 950/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.9569 - loss: 0.2338
# Epoch 951/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.9569 - loss: 0.2336
# Epoch 952/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9569 - loss: 0.2335
# Epoch 953/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9569 - loss: 0.2333
# Epoch 954/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.9569 - loss: 0.2332
# Epoch 955/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.9569 - loss: 0.2330
# Epoch 956/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.9569 - loss: 0.2328
# Epoch 957/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9569 - loss: 0.2327
# Epoch 958/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.9569 - loss: 0.2325
# Epoch 959/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.9617 - loss: 0.2324
# Epoch 960/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.9617 - loss: 0.2322
# Epoch 961/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.9617 - loss: 0.2320
# Epoch 962/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.9617 - loss: 0.2319
# Epoch 963/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.9617 - loss: 0.2317
# Epoch 964/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9617 - loss: 0.2316
# Epoch 965/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9617 - loss: 0.2314
# Epoch 966/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9617 - loss: 0.2312
# Epoch 967/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9617 - loss: 0.2311
# Epoch 968/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9617 - loss: 0.2309
# Epoch 969/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9617 - loss: 0.2308
# Epoch 970/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.9617 - loss: 0.2306
# Epoch 971/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9617 - loss: 0.2305
# Epoch 972/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9617 - loss: 0.2303
# Epoch 973/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.9617 - loss: 0.2301
# Epoch 974/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.9617 - loss: 0.2300
# Epoch 975/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9617 - loss: 0.2298
# Epoch 976/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 0.9617 - loss: 0.2297
# Epoch 977/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.9617 - loss: 0.2295
# Epoch 978/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 0.9617 - loss: 0.2294
# Epoch 979/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 0.9617 - loss: 0.2292
# Epoch 980/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.9617 - loss: 0.2290
# Epoch 981/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - accuracy: 0.9617 - loss: 0.2289
# Epoch 982/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 0.9617 - loss: 0.2287
# Epoch 983/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.9617 - loss: 0.2286
# Epoch 984/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.9617 - loss: 0.2284
# Epoch 985/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 0.9617 - loss: 0.2283
# Epoch 986/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.9617 - loss: 0.2281
# Epoch 987/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.9617 - loss: 0.2279
# Epoch 988/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9617 - loss: 0.2278
# Epoch 989/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.9617 - loss: 0.2276
# Epoch 990/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - accuracy: 0.9617 - loss: 0.2275
# Epoch 991/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.9617 - loss: 0.2273
# Epoch 992/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.9617 - loss: 0.2272
# Epoch 993/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.9617 - loss: 0.2270
# Epoch 994/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.9617 - loss: 0.2269
# Epoch 995/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.9617 - loss: 0.2267
# Epoch 996/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 0.9617 - loss: 0.2265
# Epoch 997/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.9617 - loss: 0.2264
# Epoch 998/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.9617 - loss: 0.2262
# Epoch 999/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.9617 - loss: 0.2261
# Epoch 1000/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.9617 - loss: 0.2259

# %%
# Vamos verificar quais variáveis foram salvas no processo de treinamento
history_dict = history.history
history_dict.keys()
# Out:
# dict_keys(['accuracy', 'loss'])

# %% [markdown]
# ### 4.3 - Visualização do resultado do treinamento
#
# Para sabermos como o treinamento foi realizado precisamos visualizar a função de custo e a métrica ao longo do processo de treinamento.
#
# ### Exercício #7:
#
# Implemente na célula abaixo a visualização dos resultados do treinamento. Observe que os valores da função de custo e da métrico estão no dicionário history com nomes `'loss'` e `'acc'`. Mas estes nomes podem variar, de acordo com a forma que os parâmetros foram definidos. Verifique a variável history_dict history_dict.keys() para conferir os nomes corretos.
#
# Consulte as notas de aula para relembrar como fazer os gráficos da função de custo e da métrica em função do número de épocas.

# %%
# PARA VOCÊ FAZER: visualização do resultado do treinamento

# Salva custo e exatidão em vetores
### COMECE AQUI ### (≈ 2 linhas)
custo = history_dict['loss']
exatidao = history_dict['accuracy']
### TERMINE AQUI ###

# Cria vetor de épocas
### COMECE AQUI ### (≈ 1 linha)
epocas = np.arange(1, 1001)
### TERMINE AQUI ###

# Gráfico do custo em funçaõ das épocas
### COMECE AQUI ### (≈ 5 linhas)
plt.plot(epocas, custo, label='Custo')
plt.xlabel('Época')
plt.ylabel('Custo (Função de Perda)')
plt.title('Custo em Função das Épocas')
plt.legend()
plt.grid(True)
plt.show()
### TERMINE AQUI ###

# Gráfico da exatidão em função das épocas
### COMECE AQUI ### (≈ 5 linhas)
plt.plot(epocas, exatidao, label='Custo')
plt.xlabel('Época')
plt.ylabel('Acurácia')
plt.title('Acurácia em Função das Épocas')
plt.legend()
plt.grid(True)
plt.show()
### TERMINE AQUI ###

# %% [markdown]
# **Saída esperada:**
#
# O comportamento esperado para a função de custo durante o treinamento é ela decrescer monotomicamente do início até o final. Para a exatidão, o comportamento esperado é ela aumentar durante o treinamento, apresentando algumas oscilações e alcançando um valor alto no final.
#
# Se você obteve esses resultados, então, a sua rede foi treinada de forma satisfatória e pode-se concluir que ela tem uma capacidade alta para se ajustar aos dados de treinamento.

# %% [markdown]
# ### 4.4 - Avaliação do desempenho da rede neural ###
#
# Após treinar a RNA é importante avaliar o seu desempenho com dados que não foram  utilizados no treinamento. Para isso usamos o dados de teste, que estão nos tensores test_set_x e test_set_y.
#
# ### Exercício #8:
#
# Avalie a sua rede neural calculando os valores da função de custo e da exatidão para os dados de teste usando o método evaluate. Calcule esses valores também para os dados de treinamento para poder fazer comparação.

# %%
# PARA VOCÊ FAZER: calculo do custo e exatidão para os dados de teste

# Usando método evaluate calcule o custo e a exatidão para os dados de treinamento e depois apresente os resultados
### COMECE AQUI ### (≈ 1 linha)
custo_e_metricas_train = rna.evaluate(train_set_x, train_set_y)
### TERMINE AQUI ###
print(custo_e_metricas_train)

# Usando método evaluate calcule o custo e a exatidão para os dados de teste e depois apresente os resultados
### COMECE AQUI ### (≈ 1 linha)
custo_e_metricas_test = rna.evaluate(test_set_x, test_set_y)
### TERMINE AQUI ###
print(custo_e_metricas_test)
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.9658 - loss: 0.2221
# [0.22577524185180664, 0.9617224931716919]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7196 - loss: 0.6480
# [0.6273214221000671, 0.7200000286102295]

# %% [markdown]
# **Resultados esperados:**
#
#     209/209 [==============================] - 0s 656us/sample - loss: 0.3270 - acc: 0.9091
#     [0.3269858589868226, 0.90909094]
#     50/50 [==============================] - 0s 260us/sample - loss: 0.5960 - acc: 0.7000
#     [0.5959848165512085, 0.7]
#
# **Comentários:**
#
# - A exatidação obtida com os dados de treinamento é cerca de 90%, isso significa que a sua rede é satisfatória para resolver esse problema.
#
# - A exatidão obtida com os dados de teste é de cerca de 68%. Esse resultado de fato não é muito bom para essa tarefa simples de classificação.
#
# Analisando esses dados surge uma dúvida. Porque a rede não foi capaz de apresentar um bom desempenho nos dados de teste, se os resultados foram bons nos dados de treinamento?

# %% [markdown]
# ### Exercício #9:
#
# Para avaliar melhor o desepenho da sua rede calcule as saídas previstas dos exemplos do conjunto de teste usando o método predict e a função numpy round faça um gráfico com as classes reais e previstas dos dados do conjunto de teste. Se não souber como fazer consulte as notas de aula e o notebook que desenvolvemos.

# %%
# PARA VOCÊ FAZER: calculo das classes previstas dos dados de teste

# Usando método predict calcule as classes previstas
### COMECE AQUI ### (≈ 2 linhas)
yy_prev = rna.predict(test_set_x)
yy_prev_classes = np.round(yy_prev)
### TERMINE AQUI ###

# Transforma saida prevista em números inteiros
yy_prev = np.round(yy_prev).astype(int)

# Gráfico das classes reais e previstas
### COMECE AQUI ### (≈ 7 linhas)
plt.figure(figsize=(10, 6))
plt.plot(test_set_y, label='Classes Reais', marker='o')
plt.plot(yy_prev_classes, label='Classes Previstas', marker='x')
plt.xlabel('Índice do Exemplo')
plt.ylabel('Classe')
plt.title('Comparação entre Classes Reais e Previstas')
plt.legend()
plt.grid(True)
plt.show()
### TERMINE AQUI ###
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step

# %% [markdown]
# **Saída esperada:**
#
# Veja a imagem classes_previstas_test.png fornecida com o material do trabalho

# %% [markdown]
# **Comentários:**
#
# - Uma previsão errada de classe pode ser dectada pelos círculos vermelhos, pois quando a classe prevista é igual à classe real o círculo azul é colocado em cima do vermelho tapando-o.
#
# - Provavelmente no grafico devem aparecer mais círculos azuis do que vermelhos indicando que existem mais acertos do que erros na previsão das classes.

# %% [markdown]
# Use o código a seguir, mudando a variável 'index', para você visualizar as imagens e a classe prevista dos exemplos de teste.

# %%
# Exemplo de classificação de uma imagem.
index = 3
plt.imshow(test_set_x[index,:].reshape((num_px, num_px, 3)))
print ("y = " + str(test_set_y[index]) + ", imagem é prevista como sendo uma '" + classes[np.squeeze(yy_prev[index])].decode("utf-8"))
# Out:
# y = [1], imagem é prevista como sendo uma 'cat

# %% [markdown]
# **Interpretação dos resultados:**
#
# O custo decrescendo durante o treinamento mostra que os parâmetros estão sendo ajustados de forma a que a rede está aprendendo os dados de treinamento. Como o custo obtido não é muito baixo, então, provavelmente é possível treinar ainda mais a rede para obter melhores resultados nos dados de treinamento.
#
# Tente refazer as etapas 4.2, 4.3 e 4.4, aumentando o número de épocas para algo em torno de 5000, para retreinar a rede. Você verá que o custo de treinamento diminui até praticamente zero e a exatidão aumenta para quase 100%.
#
# **Importante:** só tente treinar com mais épocas após entregar o seu trabalho, pois os resultados esperados são para o treinamento com 1000 épocas.
#
# Contudo, nem sempre é bom treinar a rede até se obter custo perto de zero e exatidão 100% para os dados de treinamento. Em geral quando isso acontece o custo e a exatidão para os dados de teste pioraram. Nesse caso, pode ocorrer que a rede está memorizando os dados de treinamento e não generalizando a solução do problema. Veremos daqui algumas aulas como resolver esse problema. Mas podemos verificar esse fato retreinando a rede para um número maior de épocas.

# %% [markdown]
# ## 5 - Desenvolvimento e teste da rede neural deep-learning ##
#
# Nessa etapa do trabalho você vai configurar, treinar e testar uma rede neural deep learning.
#
# ### Exercício #10:
#
# Usando o Keras configure e crie uma rede neural com as seguintes caracteríticas:
#
# - três camadas intermediárias com função de ativação tipo ReLu;
# - número de neurônios das camadas intermediárias: 64, 32, 16;
# - camada de saída deve possuir um único neurônio e ter função de ativação sigmóide.
#
# Essa rede deve ser criada dentro de uma função (build_model) e os argumentos dessa função são: a dimensão dos dados de entrada e os números de neurônios das diversas camadas.

# %%
# PARA VOCÊ FAZER: configuração da rede deep-learning

# Importar do Keras modelos e camadas
from tensorflow.keras import models
from tensorflow.keras import layers

def build_model(data_shape,n1,n2,n3,n4):
    """
    Essa função configura uma rede neural deep-learnig

    Argumentos:
    data_shape = tuple com dimensões dos dados de entrada da rede
    n1 = número de neurônios da primeira camada
    n2 = número de neurônios da segunda camada
    n3 = número de neurônios da terceira camada
    n4 = número de neurônios da camada de saída

    Retorna: modelo da rede neural
    """

    np.random.seed(3)

    model = models.Sequential()

    # Adicione as camadas em seu modelo de RNA
    #### COMECE AQUI ### (≈ 4 linhas)
    model.add(Dense(n1, activation='relu', input_shape=data_shape))
    model.add(Dense(n2, activation='relu'))
    model.add(Dense(n3, activation='relu'))
    model.add(Dense(n4, activation='sigmoid'))
    ### TERMINE AQUI ###

    return model

# Redefine semente para geração de números aleatórios
np.random.seed(3)

# Dimensão dos dados de entrada
data_shape = (12288,)

# Definição dos números de neurônios das camadas
#### COMECE AQUI ### (≈ 4 linhas)
n1 = 64
n2 = 32
n3 = 16
n4 = 1
### TERMINE AQUI ###

# Cria rede neural deep learning
#### COMECE AQUI ### (≈ 1 linha)
rnadl = build_model(data_shape, n1, n2, n3, n4)
### TERMINE AQUI ###
rnadl.summary()
# Out:
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_7 (Dense)                      │ (None, 64)                  │         786,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_8 (Dense)                      │ (None, 32)                  │           2,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_9 (Dense)                      │ (None, 16)                  │             528 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_10 (Dense)                     │ (None, 1)                   │              17 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 789,121 (3.01 MB)
#  Trainable params: 789,121 (3.01 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# **Saída esperada:**
#
#     Model: "sequential_1"
#     _________________________________________________________________
#     Layer (type)                 Output Shape              Param #
#     =================================================================
#     dense_2 (Dense)              (None, 64)                786496
#     _________________________________________________________________
#     dense_3 (Dense)              (None, 32)                2080
#     _________________________________________________________________
#     dense_4 (Dense)              (None, 16)                528
#     _________________________________________________________________
#     dense_5 (Dense)              (None, 1)                 17
#     =================================================================
#     Total params: 789,121
#     Trainable params: 789,121
#     Non-trainable params: 0
#     _________________________________________________________________

# %% [markdown]
# ### Exercício #11:
#
# Repita os itens 4.2, 4.3 e 4.4 para a rede neural deep-learning. Use `rnadl` como nome da rede e acrescentando as letras `dl` nas variáveis de custo, exatidao e epocas.
#
# Na célula abaixo compile e treine a sua rede deep-learning para 10 épocas. Esse treinamento é só para verificar se o programa está correto.

# %%
# PARA VOCÊ FAZER: compilação e treinamento da rede deep-learning

# Compilação da rede
### COMECE AQUI ### (≈ 2 linhas)
rnadl.compile(optimizer=optimizers.SGD(), loss='binary_crossentropy', metrics=['accuracy'])
### TERMINE AQUI ###

# Teste de treinamento da rede
### COMECE AQUI ### (≈ 1 linha)
rnadl.fit(train_set_x, train_set_y, epochs=10, batch_size=209)
### TERMINE AQUI ###
# Out:
# Epoch 1/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - accuracy: 0.3445 - loss: 0.7383
# Epoch 2/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step - accuracy: 0.5742 - loss: 0.6891
# Epoch 3/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.6124 - loss: 0.6793
# Epoch 4/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.6507 - loss: 0.6718
# Epoch 5/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.6507 - loss: 0.6659
# Epoch 6/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.6507 - loss: 0.6618
# Epoch 7/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.6507 - loss: 0.6585
# Epoch 8/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.6507 - loss: 0.6558
# Epoch 9/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.6507 - loss: 0.6535
# Epoch 10/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.6507 - loss: 0.6516

# %% [markdown]
# **Saída esparada:**
#
#     Epoch 1/10
#     209/209 [==============================] - 0s 1ms/sample - loss: 0.7339 - acc: 0.3206
#     Epoch 2/10
#     209/209 [==============================] - 0s 175us/sample - loss: 0.6939 - acc: 0.5072
#     Epoch 3/10
#     209/209 [==============================] - 0s 172us/sample - loss: 0.6786 - acc: 0.5933
#     Epoch 4/10
#     209/209 [==============================] - 0s 191us/sample - loss: 0.6661 - acc: 0.6268
#     Epoch 5/10
#     209/209 [==============================] - 0s 177us/sample - loss: 0.6588 - acc: 0.6316
#     Epoch 6/10
#     209/209 [==============================] - 0s 167us/sample - loss: 0.6529 - acc: 0.6459
#     Epoch 7/10
#     209/209 [==============================] - 0s 162us/sample - loss: 0.6479 - acc: 0.6507
#     Epoch 8/10
#     209/209 [==============================] - 0s 172us/sample - loss: 0.6433 - acc: 0.6507
#     Epoch 9/10
#     209/209 [==============================] - 0s 167us/sample - loss: 0.6391 - acc: 0.6555
#     Epoch 10/10
#     209/209 [==============================] - 0s 167us/sample - loss: 0.6359 - acc: 0.6555

# %% [markdown]
# Na célula abaixo treine a sua rede deep-learning por 1000 épocas. Use verbose = 0 e batch_size = 209.

# %%
# PARA VOCÊ FAZER: treinamento da rede deep-learning por 1000 épocas

### COMECE AQUI ### (≈ 1 linha)
historydl = rnadl.fit(train_set_x, train_set_y, epochs=1000, batch_size=209, verbose=0)
### TERMINE AQUI ###

# Vamos verificar quais variáveis foram salvas no processo de treinamento
historydl_dict = historydl.history
historydl_dict.keys()
# Out:
# dict_keys(['accuracy', 'loss'])

# %% [markdown]
# ### Exercício #12:
#
# Na célula abaixo introduza os comandos para visualizar os resultados da sua rede deep-learning.

# %%
# PARA VOCÊ FAZER: visualização do resultado do treinamento da rede deep-learning

# Salva custo e exatidão em vetores
### COMECE AQUI ### (≈ 2 linhas)
custodl = historydl_dict['loss']
exatidaodl = historydl_dict['accuracy']
### TERMINE AQUI ###

# Cria vetor de épocas
### COMECE AQUI ### (≈ 1 linha)
epocasdl = np.arange(1, 1001)
### TERMINE AQUI ###

# Gráfico do custo em funçaõ das épocas
### COMECE AQUI ### (≈ 5 linhas)
plt.plot(epocasdl, custodl, label='Custo')
plt.xlabel('Época')
plt.ylabel('Custo (Função de Perda)')
plt.title('Custo em Função das Épocas')
plt.legend()
plt.grid(True)
plt.show()
### TERMINE AQUI ###

# Gráfico da exatidão em função das épocas
### COMECE AQUI ### (≈ 5 linhas)
plt.plot(epocasdl, exatidaodl, label='Custo')
plt.xlabel('Época')
plt.ylabel('Acurácia')
plt.title('Acurácia em Função das Épocas')
plt.legend()
plt.grid(True)
plt.show()
### TERMINE AQUI ###

# %% [markdown]
# ### Exercício #13:
#
# Na célula abaixo introduza os comandos para avaliar a sua rede deep-learning para os dados de treinamento e de teste.

# %%
# PARA VOCÊ FAZER: calculo do custo e exatidão para os dados de treinamento e de teste para a rede deep-learning

# Usando método evaluate calcule o custo e a exatidão dos dados de treinamento e depois apresente os resultados
### COMECE AQUI ### (≈ 1 linha)
custo_e_metricasdl_train = rnadl.evaluate(train_set_x, train_set_y)
### TERMINE AQUI ###
print(custo_e_metricasdl_train)

# Usando método evaluate calcule o custo e a exatidão dos dados de teste e depois apresente os resultados
### COMECE AQUI ### (≈ 1 linha)
custo_e_metricasdl_test = rnadl.evaluate(test_set_x, test_set_y)
### TERMINE AQUI ###
print(custo_e_metricasdl_test)
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 1.0000 - loss: 0.0089
# [0.0098989587277174, 1.0]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 273ms/step - accuracy: 0.7567 - loss: 1.0093
# [0.9616653323173523, 0.7599999904632568]

# %% [markdown]
# **Saída esperada:**
#
#     209/209 [==============================] - 0s 482us/sample - loss: 0.0115 - acc: 1.0000
#     [0.011545336649320913, 1.0]
#     50/50 [==============================] - 0s 399us/sample - loss: 1.0013 - acc: 0.7400
#     [1.0013008093833924, 0.74]

# %% [markdown]
# ### Exercício #14:
#
# Na célula abaixo introduza os comandos para clcular as classes previstas para os dados de teste.

# %%
# PARA VOCÊ FAZER: calculo das classes previstas dos dados de teste para a rede deep-learning

# Usando método predict calcule as classes previstas
### COMECE AQUI ### (≈ 2 linhas)
yy_prevdl = rnadl.predict(test_set_x)
### TERMINE AQUI ###

# Transforma saida prevista em números inteiros
yy_prevdl = np.round(yy_prevdl).astype(int)

# Gráfico das classes reais e previstas
### COMECE AQUI ### (≈ 7 linhas)
plt.figure(figsize=(10, 6))
plt.plot(test_set_y, label='Classes Reais', marker='o')
plt.plot(yy_prevdl, label='Classes Previstas', marker='x')
plt.xlabel('Índice do Exemplo')
plt.ylabel('Classe')
plt.title('Comparação entre Classes Reais e Previstas')
plt.legend()
plt.grid(True)
plt.show()
### TERMINE AQUI ###
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step

# %% [markdown]
# **Saída esperada:**
#
# O número de erros de classificação é igual a 12 (ou 13), representado por 12 (13) bolinhas vermelhas, o que significa 76% (74%) dos 50 exemplos de teste.
#
# **Interpretação dos resultados:**
#
# Se você fez tudo correto, então, os resultados obtidos do custo e da exatidão para os dados de teste são melhores para a rede neural deep-learning do que para a rede neural rasa, como era de se esperar.
#
# Observe que a rede deep learning possui quase o mesmo número de parâmetros do que a rede rasa, mas obtém resultados mais satisfatórios.
#
# O que fez com que os resultados da rede deep learning fossem muito melhores do que a rede rasa? O número de camadas, o tipo de função de ativação, ou simplesmenete o número de parâmetros?

# %% [markdown]
# <font color='blue'>
#
# **O que é importante lembrar:**
# - A escolha do número de neurônios das camadas da rede é muito importane
# - O tipo de função de ativação usada pode fazer diferença nos resultados
# - Não é uma tarefa fácil desenvolver uma rede neural que apresenta um desempenho bom, mas não é impossível

# %% [markdown]
# ## 6 - Teste as redes que você desenvolveu com sua própria imagem (exercício opcional) ##
#
# Você pode usar qualquer imagem e verificar se as suas redes neurais são eficientes. Para fazer isso faça:
#     1. Clique em "File" na parte superior desse notebook e depois clique "Open" para ir para o seu diretório.
#     2. Adicione a sua imagem nesse diretório.
#     3. Troque o nome do arquivo onde se encontra a imagem no código abaixo.
#     4. Execute o código e verifique se a rede acerta (1 = imagem mostra gato, 0 = imagem não tem gato)!

# %%
# PARA VOCÊ FAZER: teste da rede com suas imagens

## COMECE AQUI ## (coloque o nome do arquivo com a sua imagem)
#my_image =
## TERMINE AQUI ##

# Pré-processamento da imagem para acertar dimensões.
fname = my_image
image = Image.open(fname)
my_image = image.resize((num_px, num_px), Image.ANTIALIAS)
my_image = np.array(my_image)
my_image = my_image.reshape((1, num_px*num_px*3))
my_image = my_image.astype(float)

# Previsão da rede neural
y_prev_myimage = rnadl.predict(my_image)
my_predicted_image = np.round(y_prev_myimage)
my_predicted_image = my_predicted_image.astype(int)

plt.imshow(image)
print("y = " + str(np.squeeze(my_predicted_image)) + ", sua rede prevê \"" + classes[int(np.squeeze(my_predicted_image)),].decode("utf-8") +  "\" picture.")

# %% [markdown]
# Finalmente, como sugestão, tente fazer alterações de parâmetros e executar o notebook novamente. Mas lembre-se de salvar o seu trabalho em um arquivo pdf e enviar para avaliação antes de modificar o notebook e realizar os seus testes.
#
# Algumas sugestões do que alterar:
#
# - Número de camadas;
# - Número de neurônios nas camadas;
# - Funções de ativação;
# - Tente impor um taxa de aprendizado;
# - Tente outras formas de normalizar os dados.
